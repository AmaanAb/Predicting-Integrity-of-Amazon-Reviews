# %%
import csv                               # csv reader
from sklearn.svm import LinearSVC
from nltk.classify import SklearnClassifier
from random import shuffle
from sklearn.pipeline import Pipeline

# %%
# load data from a file and append it to the rawData


def loadData(path, Text=None):
    with open(path, errors="ignore") as f:
        reader = csv.reader(f, delimiter='\t')
        for line in reader:
        #    print(line)
        #    break
            if line[0] == "DOC_ID":  # skip the header
                continue
            (Id, Text, Label) = parseReview(line)
            rawData.append((Id, Text, Label))
        


def splitData(percentage):
    # A method to split the data between trainData and testData 
    dataSamples = len(rawData)
    halfOfData = int(len(rawData)/2)
    trainingSamples = int((percentage*dataSamples)/2)
    for (_, Text, Label) in rawData[:trainingSamples] + rawData[halfOfData:halfOfData+trainingSamples]:
        trainData.append((toFeatureVector(preProcess(Text)),Label))
        # training data without label array created for cross validation function. Specifically for label prediction of validation fold
        trainData_noLab.append((toFeatureVector(preProcess(Text))))
        # training data label array created for producing accuracy metrics, comparing predicted validation dataset fold labels against the actual labels
        trainLabel.append((Label))
    for (_, Text, Label) in rawData[trainingSamples:halfOfData] + rawData[halfOfData+trainingSamples:]:
        testData.append((toFeatureVector(preProcess(Text)),Label))
        # test data without label array created for predicting test dataset label
        testData_noLab.append((toFeatureVector(preProcess(Text))))
        # test data label array created for evaluating accuracy metrics
        testLabel.append((Label))

# %% [markdown]
# # Question 4

# %%
# Convert line from input file into an id/text/label tuple
def parseReview(reviewLine):
    # Should return a triple of an integer, a string containing the review, and a string indicating the label
    # the following line of code extracts the ID, review text and label string for each line
    return (reviewLine[0], reviewLine[8], reviewLine[1])

# %%
# TEXT PREPROCESSING AND FEATURE VECTORIZATION
import re

# Input: a string of one review
def preProcess(text):
    # Should return a list of tokens
    # the following code goes through each line of text, separating the words from other characters and tokenising them.
    # the tokens from each line of text are then appended to an array "tokens" 
    text = re.sub(r"(\w)([<>.,;:!?Ã©\"”\)])", r"\1 \2", text)
    text = re.sub(r"([.,;:!<>?Ã©\"“\(])(\w)", r"\1 \2", text)
    #print("tokenising:", text)
    # no other spelling normalization done for now
    tokens = re.split(r"\s+",text)
    tokens = [t.lower() for t in tokens]
    return tokens
        
    


# original solution with for loop. Can be ignored:    
    
# def preProcess(text):
#     # Should return a list of tokens
#     # the following code goes through each line of text, separating the words from other characters and tokenising them.
#     # the tokens from each line of text are then appended to an array "Tokens" 
#     for line in text:
#         line = re.sub(r"(\w)([<>.,;:!?Ã©'\"”\)])", r"\1 \2", line)
#         line = re.sub(r"([.,;:!<>?Ã©'\"“\(])(\w)", r"\1 \2", line)
#         #print("tokenising:", text)
#         # no other spelling normalization done for now
#         tokens = re.split(r"\s+",line)
#         tokens = [t.lower() for t in tokens]
#         return tokens

# %%
featureDict = {} # A global dictionary of features

def toFeatureVector(tokens):
    # Should return a dictionary containing features as keys, and weights as values
    
    # Dictionary created to add new tokens as keys with weights as the value
    v = {}
    
    # for loop adds new token to featureDict whilst increasing the index by one, or using the index of existing token if
    # said token already exists in the dictionary
    for token in tokens:
        try:
            i = featureDict[token]
        except KeyError:
            i = len(featureDict) + 1
            featureDict[token] = i
   # for each line of text, a new token is added with it's weightage in the line as the associated value, or this is increased
   # by it's additional relative weightage if the token already exists within that line of text
        try:
            v[token] += (1.0/len(tokens))
        except KeyError:
            v[token] = (1.0/len(tokens))
    return v



# original nested for loop solution. Can be ignored:

# def toFeatureVector(tokens):
#     # Should return a dictionary containing features as keys, and weights as values
#     # DESCRIBE YOUR METHOD IN WORDS
#     v = {}
#     for line in tokens:
#         for token in line:
#             try:
#                 i = featureDict[token]
#             except KeyError:
#                 i = len(featureDict) + 1
#                 featureDict[token] = i
#             try:
#                 v[token] += (1.0/len(line))
#             except KeyError:
#                 v[token] = (1.0/len(line))
#     return v

# %% [markdown]
# ### Regularisation parameter (C) for the SVM model has been varied (0.5, 1, 2, 3, 4, 5) to find the value which produces the optimal accuracy metrics. Regularisation has potential to improve accuracy metrics via helping to counter overfitting.

# %%
# TRAINING AND VALIDATING OUR CLASSIFIER
def trainClassifier(trainData):
    print("Training Classifier...")
    pipeline =  Pipeline([('svc', LinearSVC(C=2))])
    return SklearnClassifier(pipeline).train(trainData)

# %%
if 1 == 1 and 2 == 2 and \
        3 == 3:
    print("hello")
# Out:
# hello

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


# the datashuffle function shuffles the indices for the training data, and all associated training datasets are shuffled
# according to these indices to maintain the relational aspect of the indices

def datashuffle(trainData, trainData_noLab, trainLabel):
    index_shuf = list(range(len(trainData)))
    shuffle(index_shuf)
    for i in index_shuf:
        trainData_shuf.append(trainData[i])
        trainData_noLab_shuf.append(trainData_noLab[i])
        trainLabel_shuf.append(trainLabel[i])
                               
    
def crossValidate(trainData_shuf, trainData_noLab_shuf, trainLabel_shuf, folds):
    cv_results = []
    foldSize = int(len(trainData_shuf)/folds)
    
    # for loop iterates through the folds of data in the training data based on foldsize and performs important calculations
    for i in range(0,(len(trainData_shuf)-foldSize),foldSize):
        
        # trainClassifier function is invoked to train the data on the out of fold data from the training dataset
        classifier = trainClassifier(trainData_shuf[0:i]+trainData_shuf[(i+foldSize):len(trainData_shuf)])
        
        # validation dataset for the respective fold is created
        trainData_val = trainData_noLab_shuf[i:(i+foldSize)]
        
        # label is predicted for the respective validation data fold
        label_pred = predictLabels(trainData_val, classifier)
        
        # accuracy metrics are evaluated using the predicted labels against the actual labels for the validation fold
        acc_score = accuracy_score(trainLabel_shuf[i:(i+foldSize)], label_pred)
        prec_score = precision_score(trainLabel_shuf[i:(i+foldSize)], label_pred, average='weighted')
        rec_score = recall_score(trainLabel_shuf[i:(i+foldSize)], label_pred, average='weighted')
        f_score = f1_score(trainLabel_shuf[i:(i+foldSize)], label_pred, average='weighted')
        
        # all accuracy metrics are appended to the cv_results array
        cv_results.append(acc_score)
        cv_results.append(prec_score)
        cv_results.append(rec_score)
        cv_results.append(f_score)
        
    print ("accuracy score =", (cv_results[0]+cv_results[4]+cv_results[8]+cv_results[12]+cv_results[16]+cv_results[20]+cv_results[24]+cv_results[28]+cv_results[32])/9, \
           ", precision score =", (cv_results[1]+cv_results[5]+cv_results[9]+cv_results[13]+cv_results[17]+cv_results[21]+cv_results[25]+cv_results[29]+cv_results[33])/9, \
           ", recall score =", (cv_results[2]+cv_results[6]+cv_results[10]+cv_results[14]+cv_results[18]+cv_results[22]+cv_results[26]+cv_results[30]+cv_results[34])/9, \
            ", F_score =", (cv_results[3]+cv_results[7]+cv_results[11]+cv_results[15]+cv_results[19]+cv_results[23]+cv_results[27]+cv_results[31]+cv_results[35])/9)                                          
                               
                               

# further commented code can be ignored:        
        
# def crossValidate(dataset, folds):
#     cv_results = []
#     foldSize = int(len(dataset)/folds)
#     # DESCRIBE YOUR METHOD IN WORDS
#     for i in range(0,(len(dataset)-foldSize),foldSize):
#         #not sure how to implement cross-validation here
#         classifier = trainClassifier(dataset[0:i]+dataset[(i+foldSize):len(dataset)])
#         dataset_val = train_Data_noLab[i:(i+foldSize)]
#         label_pred = predictLabels(dataset_val, classifier)
#         acc_score = accuracy_score(trainLabel[i:(i+foldSize)], label_pred)
#         prec_score = precision_score(trainLabel[i:(i+foldSize)], label_pred, average=None)
#         rec_score = recall_score(trainLabel[i:(i+foldSize)], label_pred, average=None)
#         f_score = f1_score(trainLabel[i:(i+foldSize)], label_pred, average=None)
#         cv_results.append(acc_score)
#         cv_results.append(prec_score)
#         cv_results.append(rec_score)
#         cv_results.append(f_score)
        
        #continue # Replace by code that trains and tests on the 10 folds of data in the dataset
#    return cv_results

# def crossValidate(dataset, folds):
#     dataset_shuf = []
#     train_Data_noLab_shuf = []
#     trainLabel_shuf = []
#     index_shuf = list(range(len(dataset)))
#     shuffle(index_shuf)
    
#     for i in index_shuf:
#         dataset_shuf.append(dataset[i])
#         train_Data_noLab_shuf.append(train_Data_noLab[i])
#         trainLabel_shuf.append(trainLabel[i])
#         foldSize = int(len(dataset)/folds)
#         cv_results = []
#         # DESCRIBE YOUR METHOD IN WORDS
#         for i in range(0,(len(dataset)-foldSize),foldSize):
#         #not sure how to implement cross-validation here
#             classifier = trainClassifier(dataset_shuf[0:i]+dataset_shuf[(i+foldSize):len(dataset_shuf)])
#             dataset_val = train_Data_noLab_shuf[i:(i+foldSize)]
#             label_pred = predictLabels(dataset_val, classifier)
#             acc_score = accuracy_score(trainLabel_shuf[i:(i+foldSize)], label_pred)
#             prec_score = precision_score(trainLabel_shuf[i:(i+foldSize)], label_pred, average=None)
#             rec_score = recall_score(trainLabel_shuf[i:(i+foldSize)], label_pred, average=None)
#             f_score = f1_score(trainLabel_shuf[i:(i+foldSize)], label_pred, average=None)
#             cv_results.append(acc_score)
#             cv_results.append(prec_score)
#             cv_results.append(rec_score)
#             cv_results.append(f_score)
        
#         #continue # Replace by code that trains and tests on the 10 folds of data in the dataset
#         return cv_results

# %%
# PREDICTING LABELS GIVEN A CLASSIFIER

def predictLabels(reviewSamples, classifier):
    return classifier.classify_many(reviewSamples)
    #return classifier.classify_many(map(lambda t: t[0], reviewSamples))

def predictLabel(reviewSample, classifier):
    return classifier.classify(reviewSample)
    #return classifier.classify(toFeatureVector(preProcess(reviewSample)))

# %%
# MAIN

# loading reviews
# initialize global lists that will be appended to by the methods below
rawData = []          # the filtered data from the dataset file (should be 21000 samples)
trainData = []# the pre-processed training data as a percentage of the total dataset (currently 80%, or 16800 samples)
testData = []         # the pre-processed test data as a percentage of the total dataset (currently 20%, or 4200 samples)
trainLabel = []
testLabel = []

# arrays creadted as inputs to the dataShuffle and crossValidate functions

trainData_noLab =[]
testData_noLab =[]

trainData_shuf = []
trainData_noLab_shuf = []
trainLabel_shuf = []

# the output classes
fakeLabel = 'fake'
realLabel = 'real'

# references to the data files
reviewPath = 'amazon_reviews.txt'

# Do the actual stuff (i.e. call the functions we've made)
# We parse the dataset and put it in a raw data list
print("Now %d rawData, %d trainData, %d testData" % (len(rawData), len(trainData), len(testData)),
      "Preparing the dataset...",sep='\n')
loadData(reviewPath) 

# We split the raw dataset into a set of training data and a set of test data (80/20)
# You do the cross validation on the 80% (training data)
# We print the number of training samples and the number of features before the split
print("Now %d rawData, %d trainData, %d testData" % (len(rawData), len(trainData), len(testData)),
      "Preparing training and test data...",sep='\n')
splitData(0.8)
# We print the number of training samples and the number of features after the split
print("After split, %d rawData, %d trainData, %d testData" % (len(rawData), len(trainData), len(testData)),
      "Training Samples: ", len(trainData), "Features: ", len(featureDict), sep='\n')

# Shuffle all training datasets before cross validating
datashuffle(trainData, trainData_noLab, trainLabel)

# QUESTION 3 - Make sure there is a function call here to the
# crossValidate function on the training set to get your results
crossValidate(trainData_shuf, trainData_noLab_shuf, trainLabel_shuf, 10)
# Out:
# Now 0 rawData, 0 trainData, 0 testData
# Preparing the dataset...
# Now 21000 rawData, 0 trainData, 0 testData
# Preparing training and test data...
# After split, 21000 rawData, 16800 trainData, 4200 testData
# Training Samples:
# 16800
# Features:
# 43352
# Training Classifier...
# Training Classifier...
# Training Classifier...
# Training Classifier...
# Training Classifier...
# Training Classifier...
# Training Classifier...
# Training Classifier...
# Training Classifier...
# accuracy score = 0.6612433862433863 , precision score = 0.6620623430396109 , recall score = 0.6612433862433863 , F_score = 0.6610167813658705

# %%
# check for trainData
trainData
# Out:
# [({'just': 0.019230769230769232,
#    'like': 0.038461538461538464,
#    'most': 0.019230769230769232,
#    'of': 0.019230769230769232,
#    'the': 0.09615384615384616,
#    'others': 0.019230769230769232,
#    'stated': 0.019230769230769232,
#    'inside': 0.019230769230769232,
#    'bolt': 0.019230769230769232,
#    'towards': 0.019230769230769232,
#    'lean': 0.019230769230769232,
#    'is': 0.019230769230769232,
#    'a': 0.038461538461538464,
#    'problem': 0.019230769230769232,
#    'to': 0.038461538461538464,
#    'install': 0.019230769230769232,
#    '.': 0.057692307692307696,
#    'had': 0.019230769230769232,
#    'drill': 0.019230769230769232,
#    'out': 0.019230769230769232,
#    'with': 0.019230769230769232,
#    'larger': 0.019230769230769232,
#    'bit': 0.019230769230769232,
#    'from': 0.019230769230769232,
#    'bottom': 0.019230769230769232,
#    'as': 0.019230769230769232,
#    'another': 0.019230769230769232,
#    'buyer': 0.019230769230769232,
#    'suggested': 0.019230769230769232,
#    'and': 0.038461538461538464,
#    'then': 0.019230769230769232,
#    'it': 0.019230769230769232,
#    'was': 0.019230769230769232,
#    'fine': 0.019230769230769232,
#    'look': 0.019230769230769232,
#    'will': 0.019230769230769232,
#    'protect': 0.019230769230769232,
#    'nyc': 0.004132231404958678,
#    'out': 0.004132231404958678,
#    'use': 0.008264462809917356,
#    'its': 0.004132231404958678,
#    'frame': 0.004132231404958678,
#    'as': 0.004132231404958678,
#    'stroller--or': 0.004132231404958678,
#    'used': 0.004132231404958678,
#    'until': 0.004132231404958678,
#    'decided': 0.004132231404958678,
#    'get': 0.004132231404958678,
#    'rid': 0.004132231404958678,
#    'monster': 0.004132231404958678,
#    ').<': 0.004132231404958678,
#    'br': 0.01652892561983471,
#    '/><': 0.008264462809917356,
#    '/>': 0.008264462809917356,
#    'got': 0.004132231404958678,
#    'off': 0.004132231404958678,
#    'registry': 0.004132231404958678,
#    'was': 0.004132231404958678,
#    'thankful': 0.004132231404958678,
#    'thing': 0.004132231404958678,
#    'beast': 0.004132231404958678,
#    '!<': 0.004132231404958678,
#    'husband': 0.004132231404958678,
#    'recently': 0.004132231404958678,
#    'purchased': 0.004132231404958678,
#    'comparatively': 0.004132231404958678,
#    'cheap': 0.004132231404958678,
#    'graco': 0.004132231404958678,
#    'his': 0.004132231404958678,
#    "parents'": 0.004132231404958678,
#    'home': 0.004132231404958678,
#    'loves': 0.004132231404958678,
#    'he': 0.008264462809917356,
#    'can': 0.004132231404958678,
#    'flex': 0.004132231404958678,
#    'little': 0.004132231404958678,
#    'legs': 0.004132231404958678,
#    'slept': 0.004132231404958678,
#    'well': 0.004132231404958678,
#    'like': 0.004132231404958678},
#   '__label1__'),
#  ({'these': 0.024691358024691357,
#    'were': 0.024691358024691357,
#    'purchased': 0.012345679012345678,
#    'as': 0.012345679012345678,
#    'a': 0.037037037037037035,
#    'xmas': 0.012345679012345678,
#    'gift': 0.024691358024691357,
#    ',': 0.012345679012345678,
#    'so': 0.024691358024691357,
#    'i': 0.04938271604938271,
#    'only': 0.024691358024691357,
#    'saw': 0.012345679012345678,
#    'them': 0.024691358024691357,
#    'on': 0.024691358024691357,
#    'line': 0.012345679012345678,
#    '.': 0.06172839506172839,
#    'was': 0.012345679012345678,
#    'extremely': 0.012345679012345678,
#    'happy': 0.012345679012345678,
#    'when': 0.024691358024691357,
#    'opened': 0.012345679012345678,
#    'up': 0.024691358024691357,
#    'they': 0.037037037037037035,
#    'larger': 0.012345679012345678,
#    'than': 0.012345679012345678,
#    'what': 0.012345679012345678,
#    'looked': 0.012345679012345678,
#    'very': 0.012345679012345678,
#    'high': 0.012345679012345678,
#    'quality': 0.012345679012345678,
#    'product': 0.012345679012345678,
#    'the': 0.024691358024691357,
#    'down': 0.012345679012345678,
#    'fall': 0.012345679012345678,
#    'is': 0.024691358024691357,
#    'are': 0.024691358024691357,
#    'large': 0.012345679012345678,
#    'that': 0.012345679012345678,
#    'diamond': 0.012345679012345678,
#    'not': 0.012345679012345678,
#    'really': 0.012345679012345678,
#    'noticeable': 0.012345679012345678,
#    'unless': 0.012345679012345678,
#    'you': 0.012345679012345678,
#    'close': 0.012345679012345678,
#    'would': 0.012345679012345678,
#    'recommend': 0.012345679012345678,
#    'for': 0.024691358024691357,
#    'anyone': 0.012345679012345678,
#    'who': 0.012345679012345678,
#    'wants': 0.012345679012345678,
#    'to': 0.012345679012345678,
#    'put': 0.012345679012345678,
#    'smile': 0.012345679012345678,
#    'someone': 0.012345679012345678,
#    'face': 0.012345679012345678,
#    'purchasing': 0.012345679012345678},
#   '__label2__'),
#  ({'this': 0.03571428571428571,
#    'cream': 0.03571428571428571,
#    'feels': 0.03571428571428571,
#    'good': 0.03571428571428571,
#    ',': 0.03571428571428571,
#    'however': 0.03571428571428571,
#    'it': 0.10714285714285714,
#    'does': 0.07142857142857142,
#    'not': 0.03571428571428571,
#    'seems': 0.03571428571428571,
#    'any': 0.07142857142857142,
#    'better': 0.03571428571428571,
#    'than': 0.07142857142857142,
#    'other': 0.03571428571428571,
#    '.': 0.07142857142857142,
#    'i': 0.03571428571428571,
#    'thought': 0.03571428571428571,
#    'would': 0.03571428571428571,
#    'hydrate': 0.03571428571428571,
#    'the': 0.03571428571428571,
#    'skin': 0.03571428571428571,
#    'more': 0.03571428571428571},
#   '__label2__'),
#  ({'3': 0.030303030303030304,
#    'days': 0.030303030303030304,
#    'i': 0.045454545454545456,
#    'had': 0.015151515151515152,
#    'this': 0.030303030303030304,
#    'phone': 0.030303030303030304,
#    'on': 0.015151515151515152,
#    'and': 0.030303030303030304,
#    'off': 0.015151515151515152,
#    '.': 0.045454545454545456,
#    'occasional': 0.015151515151515152,
#    'game': 0.015151515151515152,
#    'browsing': 0.015151515151515152,
#    'google': 0.015151515151515152,
#    'play': 0.030303030303030304,
#    'etc': 0.015151515151515152,
#    '<': 0.030303030303030304,
#    'br': 0.06060606060606061,
#    '/>': 0.045454545454545456,
#    'almost': 0.015151515151515152,
#    'it': 0.015151515151515152,
#    'was': 0.030303030303030304,
#    'at': 0.015151515151515152,
#    '50%': 0.015151515151515152,
#    'so': 0.015151515151515152,
#    'decided': 0.015151515151515152,
#    'to': 0.030303030303030304,
#    'charge': 0.015151515151515152,
#    '.<': 0.015151515151515152,
#    '/><': 0.015151515151515152,
#    'use': 0.015151515151515152,
#    'rarely': 0.015151515151515152,
#    ',': 0.015151515151515152,
#    'only': 0.015151515151515152,
#    'or': 0.015151515151515152,
#    'just': 0.015151515151515152,
#    'spend': 0.015151515151515152,
#    'time': 0.015151515151515152,
#    'one': 0.015151515151515152,
#    'perfect': 0.015151515151515152,
#    'cheap/powerful/fast/big': 0.015151515151515152,
#    'screen': 0.015151515151515152,
#    'what': 0.015151515151515152,
#    'else': 0.015151515151515152,
#    'would': 0.015151515151515152,
#    'u': 0.015151515151515152,
#    'want': 0.015151515151515152,
#    '?': 0.015151515151515152},
#   '__label2__'),
#  ({"it's": 0.05128205128205128,
#    'not': 0.05128205128205128,
#    'a': 0.02564102564102564,
#    'million': 0.02564102564102564,
#    'dollar': 0.02564102564102564,
#    'shoe': 0.02564102564102564,
#    'rack': 0.02564102564102564,
#    '.': 0.10256410256410256,
#    'amazingly': 0.02564102564102564,
#    'high': 0.02564102564102564,
#    'quality': 0.02564102564102564,
#    ',': 0.02564102564102564,
#    'but': 0.02564102564102564,
#    'it': 0.07692307692307693,
#    'works': 0.02564102564102564,
#    'just': 0.02564102564102564,
#    'fine': 0.02564102564102564,
#    'goes': 0.02564102564102564,
#    'together': 0.02564102564102564,
#    'easily': 0.02564102564102564,
#    'out': 0.02564102564102564,
#    'of': 0.02564102564102564,
#    'the': 0.02564102564102564,
#    'box': 0.02564102564102564,
#    'muddy': 0.02564102564102564,
#    'shoes': 0.02564102564102564,
#    'will': 0.02564102564102564,
#    'stain': 0.05128205128205128,
#    'unless': 0.02564102564102564,
#    'you': 0.02564102564102564,
#    'first': 0.02564102564102564},
#   '__label2__'),
#  ({'simple': 0.020833333333333332,
#    'to': 0.020833333333333332,
#    'use': 0.020833333333333332,
#    '.': 0.12499999999999999,
#    'just': 0.020833333333333332,
#    'wanted': 0.020833333333333332,
#    'an': 0.020833333333333332,
#    'extra': 0.020833333333333332,
#    'bit': 0.020833333333333332,
#    'and': 0.041666666666666664,
#    'depth': 0.020833333333333332,
#    'collar': 0.020833333333333332,
#    'the': 0.041666666666666664,
#    'price': 0.020833333333333332,
#    'for': 0.020833333333333332,
#    'this': 0.020833333333333332,
#    'jig': 0.041666666666666664,
#    'set': 0.020833333333333332,
#    'was': 0.020833333333333332,
#    'so': 0.020833333333333332,
#    'good': 0.020833333333333332,
#    'that': 0.020833333333333332,
#    'i': 0.041666666666666664,
#    'picked': 0.020833333333333332,
#    'it': 0.020833333333333332,
#    'up': 0.020833333333333332,
#    'instead': 0.020833333333333332,
#    'glad': 0.020833333333333332,
#    'did': 0.020833333333333332,
#    'works': 0.020833333333333332,
#    'great': 0.020833333333333332,
#    'gets': 0.020833333333333332,
#    'into': 0.020833333333333332,
#    'places': 0.020833333333333332,
#    'larger': 0.020833333333333332,
#    "won't": 0.020833333333333332,
#    'comes': 0.020833333333333332,
#    'in': 0.020833333333333332,
#    'handy': 0.020833333333333332},
#   '__label2__'),
#  ({'after': 0.007751937984496124,
#    'placing': 0.007751937984496124,
#    'my': 0.06201550387596899,
#    'order': 0.015503875968992248,
#    'it': 0.007751937984496124,
#    'was': 0.007751937984496124,
#    'in': 0.007751937984496124,
#    'mail': 0.007751937984496124,
#    'box': 0.007751937984496124,
#    '6': 0.007751937984496124,
#    'days': 0.007751937984496124,
#    'later': 0.007751937984496124,
#    '.': 0.046511627906976744,
#    'i': 0.046511627906976744,
#    'scheduled': 0.007751937984496124,
#    'eye': 0.007751937984496124,
#    'exam': 0.007751937984496124,
#    'appt': 0.007751937984496124,
#    'the': 0.031007751937984496,
#    'next': 0.007751937984496124,
#    'day': 0.007751937984496124,
#    'receptionist': 0.007751937984496124,
#    'complimented': 0.007751937984496124,
#    'stylish': 0.007751937984496124,
#    'frames': 0.015503875968992248,
#    'he': 0.015503875968992248,
#    'said': 0.007751937984496124,
#    '&#34': 0.015503875968992248,
#    ';': 0.023255813953488372,
#    'may': 0.007751937984496124,
#    'ask': 0.007751937984496124,
#    'what': 0.007751937984496124,
#    'you': 0.007751937984496124,
#    'paid': 0.007751937984496124,
#    'for': 0.007751937984496124,
#    'somewhat': 0.008771929824561403,
#    'fragile': 0.008771929824561403},
#   '__label2__'),
#  ({'i': 0.04878048780487805,
#    'gave': 0.024390243902439025,
#    'this': 0.04878048780487805,
#    'watch': 0.04878048780487805,
#    'to': 0.04878048780487805,
#    'my': 0.04878048780487805,
#    'husband': 0.04878048780487805,
#    'and': 0.04878048780487805,
#    'it': 0.04878048780487805,
#    'was': 0.04878048780487805,
#    'literally': 0.024390243902439025,
#    'love': 0.024390243902439025,
#    'at': 0.024390243902439025,
#    'first': 0.024390243902439025,
#    'sight': 0.024390243902439025,
#    '!!': 0.04878048780487805,
#    'did': 0.024390243902439025,
#    'good': 0.024390243902439025,
#    'on': 0.024390243902439025,
#    'the': 0.024390243902439025,
#    'is': 0.04878048780487805,
#    'easy': 0.024390243902439025,
#    'use': 0.024390243902439025,
#    ',': 0.024390243902439025,
#    'gorgeous': 0.024390243902439025,
#    'exactly': 0.024390243902439025,
#    'what': 0.024390243902439025,
#    'looking': 0.024390243902439025,
#    'for': 0.024390243902439025,
#    '!': 0.024390243902439025},
#   '__label2__'),
#  ({'i': 0.09375,
#    'purchased': 0.03125,
#    'this': 0.03125,
#    'as': 0.03125,
#    'a': 0.0625,
#    'christmas': 0.03125,
#    'gift': 0.03125,
#    'along': 0.03125,
#    'with': 0.03125,
#    'leather': 0.03125,
#    'cord': 0.03125,
#    'to': 0.03125,
#    'hang': 0.03125,
#    'it': 0.09375,
#    'on': 0.03125,
#    '.': 0.0625,
#    'when': 0.03125,
#    'arrived': 0.03125,
#    'liked': 0.03125,
#    'so': 0.03125,
#    'much': 0.03125,
#    'immediately': 0.03125,
#    'ordered': 0.03125,
#    'one': 0.03125,
#    'for': 0.03125,
#    'myself': 0.03125},
#   '__label2__'),
#  ({'i': 0.0975609756097561,
#    'had': 0.04878048780487805,
#    'two': 0.024390243902439025,
#    'black': 0.024390243902439025,
#    'bar': 0.04878048780487805,
#    'stools': 0.024390243902439025,
#    'and': 0.07317073170731708,
#    'was': 0.024390243902439025,
#    'looking': 0.024390243902439025,
#    'for': 0.04878048780487805,
#    'the': 0.024390243902439025,
#    'perfect': 0.024390243902439025,
#    'height': 0.024390243902439025,
#    'table': 0.024390243902439025,
#    'to': 0.04878048780487805,
#    'go': 0.024390243902439025,
#    'with': 0.04878048780487805,
#    'them': 0.024390243902439025,
#    'my': 0.024390243902439025,
#    'new': 0.024390243902439025,
#    'apartment': 0.024390243902439025,
#    '.': 0.04878048780487805,
#    'limited': 0.024390243902439025,
#    'space': 0.024390243902439025,
#    'work': 0.024390243902439025,
#    'just': 0.024390243902439025,
#    'wanted': 0.024390243902439025,
#    'something': 0.024390243902439025,
#    'simple': 0.024390243902439025,
#    'practical': 0.024390243902439025},
#   '__label1__'),
#  ({'a': 0.030612244897959183,
#    'great': 0.01020408163265306,
#    'little': 0.01020408163265306,
#    'tool': 0.02040816326530612,
#    'for': 0.030612244897959183,
#    'handy': 0.01020408163265306,
#    'woman': 0.01020408163265306,
#    ',': 0.0510204081632653,
#    'no': 0.01020408163265306,
#    'more': 0.01020408163265306,
#    'calling': 0.01020408163265306,
#    'friends': 0.01020408163265306,
#    'to': 0.02040816326530612,
#    'help': 0.01020408163265306,
#    'fixing': 0.01020408163265306,
#    'something': 0.01020408163265306,
#    'hehe': 0.01020408163265306,
#    'it': 0.07142857142857142,
#    'worked': 0.01020408163265306,
#    'this': 0.01020408163265306,
#    'time': 0.01020408163265306,
#    'and': 0.04081632653061224,
#    'i': 0.02040816326530612,
#    'was': 0.01020408163265306,
#    'very': 0.01020408163265306,
#    'proud': 0.01020408163265306,
#    'of': 0.01020408163265306,
#    'doing': 0.02040816326530612,
#    'myself': 0.01020408163265306,
#    'fixed': 0.01020408163265306,
#    'some': 0.01020408163265306,
#    'cabinet': 0.01020408163265306,
#    'door': 0.01020408163265306,
#    'also': 0.01020408163265306,
#    'replaced': 0.01020408163265306,
#    'lamp': 0.01020408163265306,
#    'in': 0.01020408163265306,
#    'the': 0.030612244897959183,
#    'bathroom': 0.01020408163265306,
#    'holder': 0.01020408163265306,
#    'is': 0.030612244897959183,
#    'good': 0.01020408163265306,
#    'if': 0.01020408163265306,
#    'you': 0.01020408163265306,
#    'need': 0.01020408163265306,
#    'extra': 0.01020408163265306,
#    'hand': 0.01020408163265306,
#    'hold': 0.01020408163265306,
#    'screw': 0.01020408163265306,
#    '..': 0.01020408163265306,
#    'really': 0.01020408163265306,
#    'powerful': 0.01020408163265306,
#    'angry': 0.01020408163265306,
#    'mosquito': 0.01020408163265306,
#    'make': 0.01020408163265306,
#    'things': 0.01020408163265306,
#    'so': 0.01020408163265306,
#    'much': 0.01020408163265306,
#    'easy': 0.01020408163265306,
#    'now': 0.01020408163265306,
#    'must': 0.01020408163265306,
#    'have': 0.01020408163265306,
#    'quick': 0.01020408163265306,
#    'fixes': 0.01020408163265306,
#    'ladies': 0.01020408163265306,
#    '!!': 0.01020408163265306,
#    'minder': 0.01020408163265306,
#    'heavy': 0.01020408163265306,
#    'as': 0.01020408163265306,
#    'our': 0.01020408163265306,
#    'iron': 0.01020408163265306,
#    'lol': 0.01020408163265306,
#    ':)': 0.01020408163265306},
#   '__label2__'),
#  ({'my': 0.024390243902439025,
#    'puppy': 0.024390243902439025,
#    'loves': 0.024390243902439025,
#    'anything': 0.024390243902439025,
#    'chewable': 0.024390243902439025,
#    ',': 0.07317073170731708,
#    'and': 0.04878048780487805,
#    'prefers': 0.024390243902439025,
#    'textured': 0.024390243902439025,
#    'items': 0.024390243902439025,
#    '.': 0.024390243902439025,
#    'these': 0.024390243902439025,
#    'are': 0.024390243902439025,
#    'a': 0.04878048780487805,
#    'hit': 0.024390243902439025,
#    'big': 0.024390243902439025,
#    'enough': 0.024390243902439025,
#    'to': 0.024390243902439025,
#    'last': 0.024390243902439025,
#    'her': 0.024390243902439025,
#    'for': 0.024390243902439025,
#    'few': 0.024390243902439025,
#    'months': 0.024390243902439025,
#    '(': 0.024390243902439025,
#    'if': 0.024390243902439025,
#    'she': 0.024390243902439025,
#    "doesn't": 0.024390243902439025,
#    'beat': 0.024390243902439025,
#    'it': 0.024390243902439025,
#    'up': 0.024390243902439025,
#    'too': 0.024390243902439025,
#    'much-': 0.024390243902439025,
#    'so': 0.04878048780487805,
#    'far': 0.024390243902439025,
#    'good': 0.024390243902439025,
#    ').': 0.024390243902439025},
#   '__label2__'),
#  ({'it': 0.07692307692307691,
#    'is': 0.07692307692307691,
#    'very': 0.038461538461538464,
#    'comfortable': 0.01282051282051282,
#    ',': 0.0641025641025641,
#    'which': 0.01282051282051282,
#    'makes': 0.02564102564102564,
#    'great': 0.01282051282051282,
#    'the': 0.038461538461538464,
#    'headrest': 0.02564102564102564,
#    'when': 0.01282051282051282,
#    'i': 0.038461538461538464,
#    'try': 0.01282051282051282,
#    'for': 0.01282051282051282,
#    'first': 0.01282051282051282,
#    'time': 0.01282051282051282,
#    'really': 0.01282051282051282,
#    'liked': 0.01282051282051282,
#    'a': 0.01282051282051282,
#    'lot': 0.01282051282051282,
#    'not': 0.01282051282051282,
#    'many': 0.01282051282051282,
#    'chairs': 0.01282051282051282,
#    'have': 0.01282051282051282,
#    'that': 0.038461538461538464,
#    'little': 0.01282051282051282,
#    'support': 0.02564102564102564,
#    'so': 0.01282051282051282,
#    'unique': 0.01282051282051282,
#    'you': 0.01282051282051282,
#    'can': 0.01282051282051282,
#    'do': 0.01282051282051282,
#    'to': 0.02564102564102564,
#    'back': 0.01282051282051282,
#    'light': 0.01282051282051282,
#    'and': 0.02564102564102564,
#    'easy': 0.01282051282051282,
#    'move': 0.01282051282051282,
#    '.': 0.038461538461538464,
#    "wasn't": 0.01282051282051282,
#    'found': 0.01282051282051282,
#    'one': 0.01282051282051282,
#    'like': 0.01282051282051282,
#    'this': 0.01282051282051282,
#    'stylish': 0.01282051282051282,
#    'perfect': 0.01282051282051282,
#    'in': 0.01282051282051282,
#    'any': 0.01282051282051282,
#    'room': 0.01282051282051282},
#   '__label1__'),
#  ({'i': 0.045454545454545456,
#    "don't": 0.015151515151515152,
#    'have': 0.015151515151515152,
#    'the': 0.015151515151515152,
#    'patience': 0.015151515151515152,
#    'for': 0.030303030303030304,
#    'high': 0.015151515151515152,
#    'maintence': 0.015151515151515152,
#    '.': 0.06060606060606061,
#    'diet': 0.015151515151515152,
#    'programs': 0.015151515151515152,
#    'and': 0.045454545454545456,
#    'apps': 0.015151515151515152,
#    'checking': 0.015151515151515152,
#    'in': 0.015151515151515152,
#    'doctor': 0.015151515151515152,
#    'appts': 0.015151515151515152,
#    'will': 0.015151515151515152,
#    'not': 0.015151515151515152,
#    'work': 0.015151515151515152,
#    'me': 0.030303030303030304,
#    'boot': 0.015151515151515152,
#    'camp': 0.015151515151515152,
#    '?': 0.015151515151515152,
#    'no': 0.015151515151515152,
#    'way': 0.015151515151515152,
#    '!': 0.015151515151515152,
#    '2': 0.030303030303030304,
#    'pills': 0.015151515151515152,
#    'a': 0.045454545454545456,
#    'day': 0.015151515151515152,
#    'half': 0.015151515151515152,
#    'hour': 0.015151515151515152,
#    'be': 0.015151515151515152,
#    'fore': 0.015151515151515152,
#    'eat': 0.015151515151515152,
#    'is': 0.030303030303030304,
#    'about': 0.015151515151515152,
#    'all': 0.030303030303030304,
#    'can': 0.015151515151515152,
#    'manage': 0.015151515151515152,
#    'few': 0.015151515151515152,
#    'pounds': 0.015151515151515152,
#    'every': 0.015151515151515152,
#    'month': 0.015151515151515152,
#    'or': 0.015151515151515152,
#    'fine': 0.015151515151515152,
#    'by': 0.015151515151515152,
#    'instead': 0.015151515151515152,
#    'of': 0.015151515151515152,
#    'that': 0.015151515151515152,
#    'nonsense': 0.015151515151515152},
#   '__label1__'),
#  ({'this': 0.034482758620689655,
#    'thing': 0.034482758620689655,
#    'broke': 0.034482758620689655,
#    'so': 0.034482758620689655,
#    'fast': 0.034482758620689655,
#    'i': 0.034482758620689655,
#    "wasn't": 0.034482758620689655,
#    'even': 0.034482758620689655,
#    'sure': 0.034482758620689655,
#    'when': 0.034482758620689655,
#    'we': 0.034482758620689655,
#    'got': 0.034482758620689655,
#    'it': 0.06896551724137931,
#    'until': 0.034482758620689655,
#    'my': 0.034482758620689655,
#    'wife': 0.034482758620689655,
#    'reminded': 0.034482758620689655,
#    'me': 0.034482758620689655,
#    '.': 0.06896551724137931,
#    'jeez': 0.034482758620689655,
#    ',': 0.034482758620689655,
#    'at': 0.034482758620689655,
#    'least': 0.034482758620689655,
#    'make': 0.034482758620689655,
#    'last': 0.034482758620689655,
#    'two': 0.034482758620689655,
#    'weeks': 0.034482758620689655},
#   '__label1__'),
#  ({"it's": 0.030303030303030304,
#    'not': 0.030303030303030304,
#    'a': 0.030303030303030304,
#    'necklace': 0.06060606060606061,
#    'that': 0.030303030303030304,
#    'u': 0.030303030303030304,
#    'can': 0.030303030303030304,
#    'wear': 0.030303030303030304,
#    'daily': 0.030303030303030304,
#    'or': 0.030303030303030304,
#    'with': 0.030303030303030304,
#    'long': 0.030303030303030304,
#    'hair': 0.06060606060606061,
#    '.': 0.030303030303030304,
#    'your': 0.030303030303030304,
#    'gets': 0.030303030303030304,
#    'tangled': 0.030303030303030304,
#    'in': 0.06060606060606061,
#    'the': 0.030303030303030304,
#    'and': 0.030303030303030304,
#    'my': 0.030303030303030304,
#    'chain': 0.030303030303030304,
#    'broke': 0.030303030303030304,
#    'less': 0.030303030303030304,
#    'than': 0.030303030303030304,
#    '2': 0.030303030303030304,
#    'weeks': 0.030303030303030304,
#    'of': 0.030303030303030304,
#    'wearing': 0.030303030303030304,
#    'it': 0.030303030303030304},
#   '__label2__'),
#  ({'what': 0.016129032258064516,
#    'a': 0.016129032258064516,
#    'waste': 0.03225806451612903,
#    'of': 0.04838709677419355,
#    'my': 0.03225806451612903,
#    'money': 0.03225806451612903,
#    '.': 0.0967741935483871,
#    'all': 0.03225806451612903,
#    'three': 0.03225806451612903,
#    'were': 0.016129032258064516,
#    'dead': 0.016129032258064516,
#    'on': 0.03225806451612903,
#    'arrival': 0.016129032258064516,
#    'not': 0.016129032258064516,
#    'one': 0.016129032258064516,
#    'them': 0.016129032258064516,
#    'was': 0.03225806451612903,
#    'good': 0.016129032258064516,
#    'right': 0.016129032258064516,
#    'out': 0.016129032258064516,
#    'the': 0.016129032258064516,
#    'box': 0.016129032258064516,
#    'had': 0.016129032258064516,
#    'printer': 0.016129032258064516,
#    'alarming': 0.016129032258064516,
#    'with': 0.016129032258064516,
#    'low': 0.016129032258064516,
#    'ink': 0.016129032258064516,
#    'alert': 0.016129032258064516,
#    ',': 0.016129032258064516,
#    'i': 0.016129032258064516,
#    'lucky': 0.016129032258064516,
#    'to': 0.016129032258064516,
#    'get': 0.016129032258064516,
#    'maybe': 0.016129032258064516,
#    '25': 0.016129032258064516,
#    'copies': 0.016129032258064516,
#    'from': 0.016129032258064516,
#    'each': 0.016129032258064516,
#    "don't": 0.016129032258064516,
#    'your': 0.016129032258064516,
#    'time': 0.016129032258064516,
#    'and': 0.016129032258064516,
#    'this': 0.016129032258064516,
#    'product': 0.016129032258064516,
#    'buy': 0.016129032258064516,
#    'new': 0.016129032258064516,
#    'instead': 0.016129032258064516},
#   '__label2__'),
#  ({'after': 0.047619047619047616,
#    'trying': 0.047619047619047616,
#    'the': 0.09523809523809523,
#    'product': 0.09523809523809523,
#    'my': 0.047619047619047616,
#    'hair': 0.047619047619047616,
#    'feels': 0.047619047619047616,
#    'smoth': 0.047619047619047616,
#    'and': 0.047619047619047616,
#    'smells': 0.047619047619047616,
#    'good': 0.047619047619047616,
#    '.': 0.09523809523809523,
#    'love': 0.047619047619047616,
#    'definitely': 0.047619047619047616,
#    'will': 0.047619047619047616,
#    'buy': 0.047619047619047616,
#    'it': 0.047619047619047616,
#    'again': 0.047619047619047616},
#   '__label1__'),
#  ({'our': 0.02,
#    'rug': 0.02,
#    'arrived': 0.02,
#    'the': 0.06,
#    'other': 0.02,
#    'day': 0.02,
#    'and': 0.06,
#    'we': 0.02,
#    'love': 0.02,
#    'it': 0.04,
#    '.': 0.04,
#    'color': 0.02,
#    'is': 0.06,
#    'a': 0.04,
#    'bright': 0.02,
#    'deep': 0.02,
#    'blue': 0.02,
#    ',': 0.06,
#    'perfect': 0.02,
#    'for': 0.04,
#    'my': 0.02,
#    'little': 0.02,
#    'boy': 0.02,
#    'abc': 0.02,
#    'letters': 0.02,
#    'are': 0.02,
#    'big': 0.02,
#    'bold': 0.02,
#    'have': 0.02,
#    'words': 0.02,
#    'associated': 0.02,
#    'with': 0.02,
#    '(': 0.02,
#    'apple': 0.02,
#    'b': 0.02,
#    'butterfly': 0.02,
#    'etc': 0.02,
#    ').': 0.02},
#   '__label2__'),
#  ({'this': 0.045454545454545456,
#    'ring': 0.06818181818181818,
#    'is': 0.06818181818181818,
#    'affordable': 0.045454545454545456,
#    'and': 0.045454545454545456,
#    'durable': 0.045454545454545456,
#    '.': 0.045454545454545456,
#    'my': 0.022727272727272728,
#    'husband': 0.022727272727272728,
#    'hard': 0.022727272727272728,
#    'on': 0.022727272727272728,
#    'his': 0.022727272727272728,
#    'wedding': 0.022727272727272728,
#    ',': 0.045454545454545456,
#    'he': 0.045454545454545456,
#    'goes': 0.022727272727272728,
#    'through': 0.022727272727272728,
#    'them': 0.045454545454545456,
#    'like': 0.022727272727272728,
#    'no': 0.022727272727272728,
#    'other': 0.022727272727272728,
#    'so': 0.022727272727272728,
#    'when': 0.022727272727272728,
#    'wears': 0.022727272727272728,
#    'out': 0.022727272727272728,
#    'i': 0.022727272727272728,
#    'can': 0.022727272727272728,
#    'easily': 0.022727272727272728,
#    'afford': 0.022727272727272728,
#    'a': 0.022727272727272728,
#    'new': 0.022727272727272728,
#    'one': 0.022727272727272728},
#   '__label2__'),
#  ({'the': 0.07692307692307691,
#    'lamp': 0.02564102564102564,
#    'was': 0.02564102564102564,
#    'shipped': 0.01282051282051282,
#    'out': 0.01282051282051282,
#    'quickly': 0.01282051282051282,
#    'and': 0.05128205128205128,
#    'arrived': 0.01282051282051282,
#    'a': 0.038461538461538464,
#    'day': 0.02564102564102564,
#    'before': 0.01282051282051282,
#    'expected': 0.01282051282051282,
#    'date': 0.01282051282051282,
#    '.': 0.038461538461538464,
#    'it': 0.02564102564102564,
#    'in': 0.02564102564102564,
#    'perfect': 0.02564102564102564,
#    'condition': 0.02564102564102564,
#    'box': 0.01282051282051282,
#    'undamaged(': 0.01282051282051282,
#    'thanks': 0.02564102564102564,
#    'ups': 0.01282051282051282,
#    '!!)removal': 0.01282051282051282,
#    'of': 0.02564102564102564,
#    'old': 0.01282051282051282,
#    'install': 0.01282051282051282,
#    'new': 0.02564102564102564,
#    'took': 0.01282051282051282,
#    'less': 0.01282051282051282,
#    'than': 0.01282051282051282,
#    '2': 0.01282051282051282,
#    'minutes': 0.01282051282051282,
#    'tv': 0.02564102564102564,
#    'is': 0.02564102564102564,
#    'back': 0.01282051282051282,
#    'operating': 0.01282051282051282,
#    'like': 0.01282051282051282,
#    'we': 0.01282051282051282,
#    'bought': 0.01282051282051282,
#    '6': 0.01282051282051282,
#    'years': 0.01282051282051282,
#    'ago': 0.01282051282051282,
#    '$40': 0.01282051282051282,
#    'for': 0.02564102564102564,
#    'quite': 0.01282051282051282,
#    'an': 0.01282051282051282,
#    'amazing': 0.01282051282051282,
#    'deal': 0.01282051282051282,
#    '!': 0.02564102564102564,
#    'great': 0.01282051282051282,
#    'product': 0.01282051282051282,
#    'service': 0.01282051282051282},
#   '__label2__'),
#  ({'i': 0.025,
#    'was': 0.025,
#    'certainly': 0.0125,
#    'inspired': 0.0125,
#    'by': 0.0125,
#    'the': 0.037500000000000006,
#    'first': 0.037500000000000006,
#    'film': 0.037500000000000006,
#    'to': 0.025,
#    'watch': 0.025,
#    'this': 0.037500000000000006,
#    'second': 0.0125,
#    'one': 0.0625,
#    '.': 0.0875,
#    'is': 0.05,
#    'good': 0.0125,
#    'too': 0.0125,
#    ';': 0.037500000000000006,
#    'yet': 0.0125,
#    'not': 0.0125,
#    'as': 0.025,
#    'superb': 0.0125,
#    'plot': 0.0125,
#    'poorer': 0.0125,
#    'and': 0.0125,
#    'weak': 0.0125,
#    'anyway': 0.0125,
#    'can': 0.0125,
#    'without': 0.0125,
#    'getting': 0.0125,
#    'board': 0.0125,
#    'a': 0.025,
#    'unique': 0.0125,
#    'have': 0.0125,
#    'never': 0.0125,
#    'watched': 0.0125,
#    'anything': 0.0125,
#    'like': 0.0125,
#    'it': 0.0125,
#    'ever': 0.0125,
#    'in': 0.0125,
#    'my': 0.0125,
#    'life': 0.0125,
#    'more': 0.0125,
#    'close': 0.0125,
#    'massacre': 0.0125,
#    'extreme': 0.0125,
#    'violence': 0.0125,
#    'but': 0.0125,
#    'that': 0.0125,
#    'all': 0.0125},
#   '__label1__'),
#  ({'i': 0.04424778761061947,
#    'had': 0.017699115044247787,
#    'a': 0.04424778761061947,
#    'project': 0.02654867256637168,
#    'that': 0.017699115044247787,
#    'was': 0.02654867256637168,
#    'going': 0.008849557522123894,
#    'to': 0.05309734513274336,
#    'require': 0.008849557522123894,
#    'over': 0.008849557522123894,
#    '500': 0.008849557522123894,
#    'rivets': 0.02654867256637168,
#    '.': 0.07964601769911504,
#    'impossible': 0.008849557522123894,
#    'do': 0.008849557522123894,
#    'by': 0.008849557522123894,
#    'hand': 0.008849557522123894,
#    'tried': 0.008849557522123894,
#    'find': 0.008849557522123894,
#    'pneumatic': 0.008849557522123894,
#    'air': 0.008849557522123894,
#    'riveter': 0.008849557522123894,
#    'rent': 0.008849557522123894,
#    'at': 0.008849557522123894,
#    'rental': 0.008849557522123894,
#    'tool': 0.008849557522123894,
#    'store': 0.008849557522123894,
#    'but': 0.008849557522123894,
#    'came': 0.017699115044247787,
#    'up': 0.008849557522123894,
#    'empty': 0.008849557522123894,
#    'so': 0.008849557522123894,
#    'buy': 0.017699115044247787,
#    'one': 0.02654867256637168,
#    'even': 0.008849557522123894,
#    'though': 0.008849557522123894,
#    'may': 0.008849557522123894,
#    'only': 0.008849557522123894,
#    'use': 0.008849557522123894,
#    'it': 0.02654867256637168,
#    'very': 0.008849557522123894,
#    'little': 0.008849557522123894,
#    ',': 0.017699115044247787,
#    "i'm": 0.008849557522123894,
#    'glad': 0.008849557522123894,
#    'bought': 0.008849557522123894,
#    'worth': 0.008849557522123894,
#    'every': 0.008849557522123894,
#    'penny': 0.008849557522123894,
#    'as': 0.008849557522123894,
#    'my': 0.008849557522123894,
#    'together': 0.008849557522123894,
#    'in': 0.008849557522123894,
#    'just': 0.017699115044247787,
#    'couple': 0.008849557522123894,
#    'of': 0.017699115044247787,
#    'days': 0.008849557522123894,
#    'thanks': 0.008849557522123894,
#    'this': 0.017699115044247787,
#    'gun': 0.008849557522123894,
#    'if': 0.008849557522123894,
#    'you': 0.008849557522123894,
#    'have': 0.008849557522123894,
#    'has': 0.008849557522123894,
#    'more': 0.008849557522123894,
#    'than': 0.008849557522123894,
#    '50': 0.008849557522123894,
#    'these': 0.008849557522123894,
#    'fine': 0.008849557522123894,
#    'for': 0.008849557522123894,
#    '1': 0.008849557522123894,
#    'inch': 0.008849557522123894,
#    'worked': 0.008849557522123894,
#    'flawlessly': 0.008849557522123894},
#   '__label2__'),
#  ({'i': 0.05128205128205128,
#    'had': 0.05128205128205128,
#    'this': 0.02564102564102564,
#    'one': 0.02564102564102564,
#    'before': 0.02564102564102564,
#    'and': 0.05128205128205128,
#    'lost': 0.02564102564102564,
#    'it': 0.05128205128205128,
#    'when': 0.02564102564102564,
#    'moved': 0.02564102564102564,
#    '..': 0.05128205128205128,
#    'looked': 0.02564102564102564,
#    'long': 0.02564102564102564,
#    'time': 0.02564102564102564,
#    'to': 0.02564102564102564,
#    'find': 0.02564102564102564,
#    'again': 0.02564102564102564,
#    '...': 0.02564102564102564,
#    'best': 0.02564102564102564,
#    'peeler': 0.02564102564102564,
#    'ever': 0.02564102564102564,
#    'my': 0.05128205128205128,
#    'hands': 0.02564102564102564,
#    'are': 0.02564102564102564,
#    'very': 0.02564102564102564,
#    'crippled': 0.02564102564102564,
#    'thi': 0.02564102564102564,
#    'is': 0.02564102564102564,
#    'so': 0.02564102564102564,
#    'comfortable': 0.02564102564102564,
#    'on': 0.02564102564102564,
#    'hand': 0.02564102564102564,
#    '.': 0.02564102564102564},
#   '__label2__'),
#  ({'i': 0.041666666666666664,
#    'bought': 0.041666666666666664,
#    'flips': 0.041666666666666664,
#    'audio': 0.020833333333333332,
#    'for': 0.041666666666666664,
#    'my': 0.020833333333333332,
#    'brother': 0.020833333333333332,
#    'who': 0.020833333333333332,
#    'is': 0.020833333333333332,
#    'a': 0.020833333333333332,
#    'headphone': 0.020833333333333332,
#    'junkie': 0.020833333333333332,
#    '.': 0.041666666666666664,
#    'he': 0.041666666666666664,
#    'jumps': 0.020833333333333332,
#    'from': 0.020833333333333332,
#    'one': 0.020833333333333332,
#    'pair': 0.020833333333333332,
#    'of': 0.020833333333333332,
#    'headphones': 0.020833333333333332,
#    'to': 0.020833333333333332,
#    'another': 0.020833333333333332,
#    'almost': 0.020833333333333332,
#    'every': 0.020833333333333332,
#    'month': 0.020833333333333332,
#    "he's": 0.020833333333333332,
#    'kept': 0.020833333333333332,
#    'since': 0.020833333333333332,
#    'them': 0.041666666666666664,
#    'him': 0.020833333333333332,
#    'off': 0.020833333333333332,
#    'their': 0.020833333333333332,
#    'website': 0.020833333333333332,
#    'about': 0.020833333333333332,
#    '3': 0.020833333333333332,
#    'months': 0.020833333333333332,
#    'ago': 0.020833333333333332,
#    'and': 0.020833333333333332,
#    'absolutely': 0.020833333333333332,
#    'loves': 0.020833333333333332,
#    '!': 0.020833333333333332},
#   '__label1__'),
#  ({'this': 0.0625,
#    'liner': 0.0625,
#    'would': 0.0625,
#    'be': 0.03125,
#    'great': 0.03125,
#    'if': 0.03125,
#    'it': 0.03125,
#    "wasn't": 0.03125,
#    'too': 0.0625,
#    'wide': 0.03125,
#    'and': 0.03125,
#    'short': 0.03125,
#    '.': 0.03125,
#    'i': 0.0625,
#    'have': 0.03125,
#    'to': 0.03125,
#    'hang': 0.03125,
#    'my': 0.03125,
#    'curtain': 0.03125,
#    'rod': 0.03125,
#    'lower': 0.03125,
#    'than': 0.03125,
#    ',': 0.03125,
#    'so': 0.03125,
#    'that': 0.03125,
#    'fits': 0.03125,
#    'properly': 0.03125},
#   '__label1__'),
#  ({'this': 0.01818181818181818,
#    'is': 0.01818181818181818,
#    'a': 0.07272727272727272,
#    'must': 0.01818181818181818,
#    'have': 0.01818181818181818,
#    'to': 0.03636363636363636,
#    'keep': 0.03636363636363636,
#    'your': 0.01818181818181818,
#    'dewalt': 0.03636363636363636,
#    'vac': 0.01818181818181818,
#    'sucking': 0.01818181818181818,
#    'like': 0.03636363636363636,
#    'champ': 0.01818181818181818,
#    '.': 0.07272727272727272,
#    'i': 0.03636363636363636,
#    'clean': 0.03636363636363636,
#    'spare': 0.01818181818181818,
#    'always': 0.01818181818181818,
#    'just': 0.01818181818181818,
#    'because': 0.01818181818181818,
#    'sometimes': 0.01818181818181818,
#    'simply': 0.01818181818181818,
#    'do': 0.01818181818181818,
#    'not': 0.01818181818181818,
#    'feel': 0.01818181818181818,
#    'stopping': 0.01818181818181818,
#    'job': 0.01818181818181818,
#    'my': 0.01818181818181818,
#    'filter': 0.01818181818181818,
#    'these': 0.01818181818181818,
#    'filters': 0.01818181818181818,
#    'are': 0.01818181818181818,
#    'cleanable': 0.01818181818181818,
#    ',': 0.01818181818181818,
#    'reusable': 0.01818181818181818,
#    'and': 0.01818181818181818,
#    'robust': 0.01818181818181818,
#    'as': 0.01818181818181818,
#    'hell': 0.01818181818181818,
#    'another': 0.01818181818181818,
#    'quality': 0.01818181818181818,
#    'product': 0.01818181818181818,
#    'from': 0.01818181818181818},
#   '__label2__'),
#  ({'item': 0.04,
#    'as': 0.04,
#    'described': 0.04,
#    '.': 0.08,
#    'movie': 0.08,
#    'was': 0.04,
#    'alright': 0.04,
#    'not': 0.04,
#    'quite': 0.04,
#    'my': 0.04,
#    'interest': 0.04,
#    'but': 0.04,
#    'good': 0.04,
#    'more': 0.04,
#    'of': 0.04,
#    'a': 0.04,
#    'business': 0.04,
#    'person': 0.04,
#    'type': 0.04,
#    'enjoyed': 0.04,
# ...
#    'two': 0.01020408163265306,
#    'months': 0.01020408163265306},
#   '__label2__'),
#  ({'i': 0.037037037037037035,
#    'like': 0.037037037037037035,
#    'it': 0.037037037037037035,
#    'very': 0.037037037037037035,
#    'much': 0.037037037037037035,
#    ',': 0.1111111111111111,
#    'because': 0.037037037037037035,
#    'of': 0.037037037037037035,
#    'good': 0.037037037037037035,
#    'quality': 0.037037037037037035,
#    'and': 0.037037037037037035,
#    'cheap': 0.037037037037037035,
#    'buy': 0.037037037037037035,
#    'products': 0.037037037037037035,
#    'consistent': 0.037037037037037035,
#    'with': 0.037037037037037035,
#    'what': 0.037037037037037035,
#    'you': 0.037037037037037035,
#    'want': 0.037037037037037035,
#    "i'll": 0.037037037037037035,
#    'tell': 0.037037037037037035,
#    'my': 0.037037037037037035,
#    'friend': 0.037037037037037035,
#    'recommended': 0.037037037037037035,
#    '!!!!!': 0.037037037037037035},
#   '__label1__'),
#  ({'sometimes': 0.017241379310344827,
#    'i': 0.017241379310344827,
#    'find': 0.017241379310344827,
#    'it': 0.017241379310344827,
#    'amusing': 0.017241379310344827,
#    'that': 0.017241379310344827,
#    'amazon': 0.017241379310344827,
#    'are': 0.009174311926605505,
#    'less': 0.009174311926605505,
#    '!': 0.009174311926605505},
#   '__label1__'),
#  ({'i': 0.0449438202247191,
#    'have': 0.011235955056179775,
#    'the': 0.02247191011235955,
#    'very': 0.011235955056179775,
#    'first': 0.011235955056179775,
#    'sega': 0.02247191011235955,
#    'genesis': 0.011235955056179775,
#    'system': 0.02247191011235955,
#    'to': 0.0449438202247191,
#    'come': 0.02247191011235955,
#    'out': 0.011235955056179775,
#    'still': 0.011235955056179775,
#    'from': 0.011235955056179775,
#    'my': 0.0449438202247191,
#    'childhood': 0.011235955056179775,
#    '.': 0.056179775280898875,
#    "it's": 0.011235955056179775,
#    'always': 0.011235955056179775,
#    'worked': 0.011235955056179775,
#    ',': 0.0449438202247191,
#    'but': 0.011235955056179775,
#    'when': 0.011235955056179775,
#    'tried': 0.011235955056179775,
#    'plug': 0.011235955056179775,
#    'it': 0.02247191011235955,
#    'directly': 0.011235955056179775,
#    'into': 0.011235955056179775,
#    'flat': 0.011235955056179775,
#    'screen': 0.011235955056179775,
#    'picture': 0.011235955056179775,
#    "wouldn't": 0.011235955056179775,
#    'up': 0.02247191011235955,
#    'so': 0.011235955056179775,
#    'after': 0.011235955056179775,
#    'being': 0.02247191011235955,
#    'told': 0.011235955056179775,
#    'by': 0.011235955056179775,
#    'other': 0.011235955056179775,
#    'people': 0.011235955056179775,
#    'buy': 0.011235955056179775,
#    'a': 0.011235955056179775,
#    'new': 0.011235955056179775,
#    "that'll": 0.011235955056179775,
#    'play': 0.02247191011235955,
#    'and': 0.02247191011235955,
#    'me': 0.011235955056179775,
#    'too': 0.011235955056179775,
#    'nostalgic': 0.011235955056179775,
#    'give': 0.011235955056179775,
#    'old': 0.011235955056179775,
#    'school': 0.011235955056179775,
#    'found': 0.011235955056179775,
#    'this': 0.011235955056179775,
#    'such': 0.011235955056179775,
#    'an': 0.011235955056179775,
#    'easy': 0.011235955056179775,
#    'fix': 0.011235955056179775,
#    'now': 0.011235955056179775,
#    'can': 0.011235955056179775,
#    'aladdin': 0.011235955056179775,
#    'sonic': 0.011235955056179775,
#    "'til": 0.011235955056179775,
#    "heart's": 0.011235955056179775,
#    'content': 0.011235955056179775},
#   '__label2__'),
#  ({'i': 0.056179775280898875,
#    'require': 0.011235955056179775,
#    'quality': 0.02247191011235955,
#    'and': 0.033707865168539325,
#    'freshness': 0.011235955056179775,
#    'when': 0.011235955056179775,
#    'cooking': 0.011235955056179775,
#    'baking': 0.011235955056179775,
#    '.': 0.056179775280898875,
#    'this': 0.033707865168539325,
#    'product': 0.02247191011235955,
#    'has': 0.011235955056179775,
#    'both': 0.011235955056179775,
#    ',': 0.011235955056179775,
#    'keep': 0.011235955056179775,
#    'a': 0.02247191011235955,
#    'bag': 0.011235955056179775,
#    'in': 0.011235955056179775,
#    'the': 0.0449438202247191,
#    'refrigerator': 0.011235955056179775,
#    'on': 0.011235955056179775,
#    'hand': 0.011235955056179775,
#    'at': 0.011235955056179775,
#    'all': 0.011235955056179775,
#    'times': 0.011235955056179775,
#    'little': 0.011363636363636364,
#    'bit': 0.011363636363636364,
#    'muscular': 0.011363636363636364,
#    'or': 0.011363636363636364,
#    'chubby': 0.011363636363636364,
#    'you': 0.011363636363636364,
#    'might': 0.011363636363636364,
#    'want': 0.011363636363636364,
#    'to': 0.011363636363636364,
#    'go': 0.011363636363636364,
#    'different': 0.011363636363636364,
#    'one': 0.011363636363636364,
#    'arrived': 0.011363636363636364,
#    'quickly': 0.011363636363636364,
#    'packaged': 0.011363636363636364,
#    'well': 0.011363636363636364,
#    'so': 0.011363636363636364,
#    'seller': 0.011363636363636364,
#    'deserves': 0.011363636363636364,
#    'few': 0.011363636363636364,
#    'stars': 0.011363636363636364,
#    'that': 0.011363636363636364},
#   '__label2__'),
#  ({'frame': 0.015384615384615385,
#    'has': 0.015384615384615385,
#    'a': 0.06153846153846154,
#    'soft': 0.015384615384615385,
#    'touch': 0.015384615384615385,
#    'coating': 0.015384615384615385,
#    'that': 0.03076923076923077,
#    'is': 0.03076923076923077,
#    'really': 0.015384615384615385,
#    'cool': 0.015384615384615385,
#    '.': 0.03076923076923077,
#    'i': 0.046153846153846156,
#    'spend': 0.015384615384615385,
#    '10+': 0.015384615384615385,
#    'hours': 0.015384615384615385,
#    'day': 0.015384615384615385,
#    'staring': 0.015384615384615385,
#    'at': 0.03076923076923077,
#    'computer': 0.015384615384615385,
#    ',': 0.03076923076923077,
#    'these': 0.015384615384615385,
#    'things': 0.015384615384615385,
#    'literally': 0.015384615384615385,
#    'saved': 0.015384615384615385,
#    'my': 0.015384615384615385,
#    'eyes': 0.015384615384615385,
#    'and': 0.015384615384615385,
#    "don't": 0.015384615384615385,
#    'get': 0.015384615384615385,
#    'headaches': 0.015384615384615385,
#    'anymore': 0.015384615384615385,
#    '.<': 0.015384615384615385,
#    'br': 0.03076923076923077,
#    '/><': 0.015384615384615385,
#    '/>': 0.015384615384615385,
#    'only': 0.015384615384615385,
#    'thing': 0.015384615384615385,
#    'to': 0.03076923076923077,
#    'be': 0.015384615384615385,
#    'aware': 0.015384615384615385,
#    'of': 0.015384615384615385,
#    'they': 0.015384615384615385,
#    'make': 0.015384615384615385,
#    'this': 0.015384615384615385,
#    'in': 0.015384615384615385,
#    'clear': 0.015384615384615385,
#    'lens': 0.015384615384615385,
#    'like': 0.015384615384615385,
#    'use': 0.015384615384615385,
#    'the': 0.015384615384615385,
#    'crystalline': 0.015384615384615385,
#    'sometimes': 0.015384615384615385,
#    'work': 0.015384615384615385},
#   '__label1__'),
#  ...]

# %%
# check for featureDict
featureDict
# Out:
# {'when': 1,
#  'least': 2,
#  'you': 3,
#  'think': 4,
#  'so': 5,
#  ',': 6,
#  'this': 7,
#  'product': 8,
#  'will': 9,
#  'save': 10,
#  'the': 11,
#  'day': 12,
#  '.': 13,
#  'just': 14,
#  'keep': 15,
#  'it': 16,
#  'around': 17,
#  'in': 18,
#  'case': 19,
#  'need': 20,
#  'for': 21,
#  'something': 22,
#  'lithium': 23,
#  'batteries': 24,
#  'are': 25,
#  'new': 26,
#  'introduced': 27,
#  'market': 28,
#  'there': 29,
#  'average': 30,
#  'developing': 31,
#  'cost': 32,
#  'is': 33,
#  'relatively': 34,
#  'high': 35,
#  'but': 36,
#  'stallion': 37,
#  "doesn't": 38,
#  'compromise': 39,
#  'on': 40,
#  'quality': 41,
#  'and': 42,
#  'provides': 43,
#  'us': 44,
#  'with': 45,
#  'best': 46,
#  'at': 47,
#  'a': 48,
#  'low': 49,
#  '.<': 50,
#  'br': 51,
#  '/>': 52,
#  'many': 53,
#  'built': 54,
#  'technical': 55,
#  'assistants': 56,
#  'that': 57,
#  'act': 58,
#  'like': 59,
#  'sensor': 60,
#  'their': 61,
#  'particular': 62,
#  'fort': 63,
#  'ã©.': 64,
#  'battery': 65,
#  'keeps': 66,
#  'my': 67,
#  'phone': 68,
#  'charged': 69,
#  'up': 70,
#  'works': 71,
#  'every': 72,
#  'voltage': 73,
#  'never': 74,
#  'risked': 75,
#  'i': 76,
#  'purchased': 77,
#  'swing': 78,
#  'baby': 79,
#  'she': 80,
#  '6': 81,
#  'months': 82,
#  'now': 83,
#  'has': 84,
#  'pretty': 85,
#  'much': 86,
#  'out': 87,
#  'grown': 88,
#  'very': 89,
#  'loud': 90,
#  'well': 91,
#  'beautiful': 92,
#  'though': 93,
#  'love': 94,
#  'colors': 95,
#  'lot': 96,
#  'of': 97,
#  'settings': 98,
#  "don't": 99,
#  'was': 100,
#  'worth': 101,
#  'money': 102,
#  'looking': 103,
#  'an': 104,
#  'inexpensive': 105,
#  'desk': 106,
#  'calcolatur': 107,
#  'here': 108,
#  'does': 109,
#  'everything': 110,
#  'only': 111,
#  'issue': 112,
#  'tilts': 113,
#  'slightly': 114,
#  'to': 115,
#  'one': 116,
#  'side': 117,
#  'hit': 118,
#  'any': 119,
#  'keys': 120,
#  'rocks': 121,
#  'little': 122,
#  'bit': 123,
#  'not': 124,
#  'big': 125,
#  'deal': 126,
#  'use': 127,
#  'twice': 128,
#  'week': 129,
#  'results': 130,
#  'great': 131,
#  'have': 132,
#  'used': 133,
#  'other': 134,
#  'teeth': 135,
#  'whitening': 136,
#  'solutions': 137,
#  'most': 138,
#  'them': 139,
#  'same': 140,
#  'would': 141,
#  'three': 142,
#  'times': 143,
#  'using': 144,
#  'because': 145,
#  'potency': 146,
#  'solution': 147,
#  'also': 148,
#  'technique': 149,
#  'trays': 150,
#  'mouth': 151,
#  "i'm": 152,
#  'sure': 153,
#  'what': 154,
#  'supposed': 155,
#  'be': 156,
#  'recommend': 157,
#  'do': 158,
#  'more': 159,
#  'research': 160,
#  'into': 161,
#  'culture': 162,
#  'pipes': 163,
#  'if': 164,
#  'plan': 165,
#  'giving': 166,
#  'as': 167,
#  'gift': 168,
#  'or': 169,
#  'yourself': 170,
#  'pleased': 171,
#  'ping': 172,
#  'pong': 173,
#  'table': 174,
#  '11': 175,
#  'year': 176,
#  'old': 177,
#  '13': 178,
#  'having': 179,
#  'blast': 180,
#  'plus': 181,
#  'lots': 182,
#  'family': 183,
#  'entertainment': 184,
#  'too': 185,
#  'better': 186,
#  'than': 187,
#  'kids': 188,
#  'sitting': 189,
#  'video': 190,
#  'games': 191,
#  'all': 192,
#  'friend': 193,
#  'put': 194,
#  'together': 195,
#  'believe': 196,
#  'challenge': 197,
#  'nothing': 198,
#  'they': 199,
#  'could': 200,
#  'handle': 201,
#  'vitamin': 202,
#  'c': 203,
#  'serum': 204,
#  '...': 205,
#  'really': 206,
#  'oil': 207,
#  'feeling': 208,
#  'sticky': 209,
#  'last': 210,
#  'some': 211,
#  'recent': 212,
#  'bug': 213,
#  'bites': 214,
#  'helps': 215,
#  'heal': 216,
#  'skin': 217,
#  'faster': 218,
#  'normal': 219,
#  "i've": 220,
#  'tide': 221,
#  'pods': 222,
#  'laundry': 223,
#  'detergent': 224,
#  'years': 225,
#  'its': 226,
#  'such': 227,
#  'nice': 228,
#  'scent': 229,
#  'leaver': 230,
#  'cloths': 231,
#  'smelling': 232,
#  'fresh': 233,
#  'everybody': 234,
#  'wants': 235,
#  'fall': 236,
#  'promises': 237,
#  'unheard': 238,
#  'brand': 239,
#  'even': 240,
#  'say': 241,
#  'non': 242,
#  'existant': 243,
#  'company': 244,
#  'look': 245,
#  'how': 246,
#  'amateur': 247,
#  'labels': 248,
#  'products': 249,
#  'ask': 250,
#  'trust': 251,
#  'kind': 252,
#  'stuff': 253,
#  '?': 254,
#  'no': 255,
#  'way': 256,
#  '!': 257,
#  'waste': 258,
#  'your': 259,
#  'unfortunately': 260,
#  "didn't": 261,
#  'work': 262,
#  'me': 263,
#  'made': 264,
#  'sick': 265,
#  'throw': 266,
#  'once': 267,
#  'two': 268,
#  'tried': 269,
#  'kettle': 270,
#  'daughter': 271,
#  'said': 272,
#  'easy': 273,
#  'likes': 274,
#  'design': 275,
#  'neat': 276,
#  'tumbler': 277,
#  'drinks': 278,
#  'warm': 279,
#  'cold': 280,
#  'good': 281,
#  'period': 282,
#  'time': 283,
#  'sturdy': 284,
#  'get': 285,
#  'complements': 286,
#  'sleek': 287,
#  'looks': 288,
#  'especially': 289,
#  'doesnt': 290,
#  'leave': 291,
#  'fingerprints': 292,
#  'highly': 293,
#  'suggestion': 294,
#  'washing': 295,
#  'lid': 296,
#  'shake': 297,
#  'dry': 298,
#  'prevent': 299,
#  'dripping': 300,
#  '3': 301,
#  'stars': 302,
#  'cheap': 303,
#  'mild': 304,
#  'sedative': 305,
#  'effect': 306,
#  "it's": 307,
#  'useless': 308,
#  'stress/anxiety/panic': 309,
#  'attacks': 310,
#  'ad': 311,
#  'zenrx': 312,
#  'night': 313,
#  'difference': 314,
#  '.[[asin': 315,
#  ':': 316,
#  'b00hbgbry4': 317,
#  '-': 318,
#  'dietary': 319,
#  'supplement': 320,
#  'reduces': 321,
#  'symptoms': 322,
#  'anxiety': 323,
#  'stress': 324,
#  'depression': 325,
#  'panic': 326,
#  'boost': 327,
#  'mood': 328,
#  'increase': 329,
#  'relaxation': 330,
#  'beat': 331,
#  'kava': 332,
#  '5-htp': 333,
#  'theanine': 334,
#  'gaba': 335,
#  'back': 336,
#  'guarantee': 337,
#  '!]]': 338,
#  'bought': 339,
#  '2': 340,
#  'these': 341,
#  'brown': 342,
#  'island': 343,
#  'hydraulic': 344,
#  'mechanism': 345,
#  'might': 346,
#  'fail': 347,
#  'over': 348,
#  'otherwise': 349,
#  'color': 350,
#  'accurate': 351,
#  'description': 352,
#  'padding': 353,
#  'definitely': 354,
#  'chair': 355,
#  'lounge': 356,
#  'bar/counter': 357,
#  'kitchen': 358,
#  'wonderful': 359,
#  'headphones': 360,
#  'had': 361,
#  '5': 362,
#  'price': 363,
#  'sound': 364,
#  'clear': 365,
#  'soft': 366,
#  'ears': 367,
#  'mention': 368,
#  'sony': 369,
#  'superb': 370,
#  'fits': 371,
#  'fine': 372,
#  'real': 373,
#  'mirror': 374,
#  '(': 375,
#  'enhanced': 376,
#  '),': 377,
#  'gripe': 378,
#  'wish': 379,
#  'cameras': 380,
#  'by': 381,
#  'due': 382,
#  'where': 383,
#  'left': 384,
#  'camera': 385,
#  'place': 386,
#  'wasted': 387,
#  'recording': 388,
#  'room': 389,
#  'start': 390,
#  'turn': 391,
#  'towards': 392,
#  'driver': 393,
#  'happy': 394,
#  'far': 395,
#  'sling': 396,
#  'shots': 397,
#  'go': 398,
#  'enough': 399,
#  'purposes': 400,
#  'preferred': 401,
#  'slimmer': 402,
#  'grip': 403,
#  'fair': 404,
#  'slicer': 405,
#  'idea': 406,
#  'tricks': 407,
#  'spiral': 408,
#  'mean': 409,
#  'manual': 410,
#  'been': 411,
#  'helpful': 412,
#  '/><': 413,
#  'saying': 414,
#  'negative': 415,
#  'about': 416,
#  'however': 417,
#  'did': 418,
#  'took': 419,
#  'almost': 420,
#  'trying': 421,
#  'learn': 422,
#  'cutting': 423,
#  'different': 424,
#  'kinds': 425,
#  'vegetable': 426,
#  'may': 427,
#  'were': 428,
#  'manuals': 429,
#  'box': 430,
#  'showing': 431,
#  'properly': 432,
#  'tablets': 433,
#  'secure': 434,
#  'dental': 435,
#  'adhesive': 436,
#  'father': 437,
#  'he': 438,
#  'satisfied': 439,
#  'decent': 440,
#  'shown': 441,
#  'photos': 442,
#  'thank': 443,
#  'amazon': 444,
#  'saved': 445,
#  'paint': 446,
#  'type': 447,
#  'costly': 448,
#  'digitally': 449,
#  'print': 450,
#  'find': 451,
#  'older': 452,
#  'harder': 453,
#  'lose': 454,
#  'weight': 455,
#  '....': 456,
#  'gotten': 457,
#  'taking': 458,
#  'garcinia': 459,
#  'month': 460,
#  'take': 461,
#  'before': 462,
#  'breakfast': 463,
#  'lunch': 464,
#  'supper': 465,
#  'after': 466,
#  'tend': 467,
#  'eat': 468,
#  'late': 469,
#  'evenings': 470,
#  'cuts': 471,
#  'down': 472,
#  'appetite': 473,
#  'lost': 474,
#  '8': 475,
#  'lbs': 476,
#  'which': 477,
#  'long': 478,
#  'weeks': 479,
#  'pictures': 480,
#  '!!': 481,
#  'recommended': 482,
#  'buy': 483,
#  'suggested': 484,
#  'dosage': 485,
#  'felt': 486,
#  'extra': 487,
#  'energy': 488,
#  'loss': 489,
#  'pounds': 490,
#  'actual': 491,
#  'power': 492,
#  'supply': 493,
#  'cable': 494,
#  "harness's": 495,
#  'completely': 496,
#  'taken': 497,
#  'apart': 498,
#  're-oriented': 499,
#  'avoid': 500,
#  'birds': 501,
#  'nest': 502,
#  'backwards': 503,
#  'wiring': 504,
#  'tower': 505,
#  'test': 506,
#  'see': 507,
#  'personal': 508,
#  'physician': 509,
#  'goo': 510,
#  'gl/wa7ai': 511,
#  '$10': 512,
#  'off': 513,
#  'free': 514,
#  'samples': 515,
#  '!!!!!<': 516,
#  'told': 517,
#  'enormous': 518,
#  'benifit': 519,
#  'oregano': 520,
#  'powerful': 521,
#  'healing': 522,
#  'herbs': 523,
#  'natural': 524,
#  'anti-biotics': 525,
#  'ever': 526,
#  'studied': 527,
#  'found': 528,
#  'study': 529,
#  'significantly': 530,
#  '18': 531,
#  'currently': 532,
#  'treatment': 533,
#  'mrsa': 534,
#  'staph': 535,
#  'infections': 536,
#  'strong': 537,
#  'phenol': 538,
#  'anti-oxidants': 539,
#  'destroy': 540,
#  'pathogenic': 541,
#  'bacteria': 542,
#  'viruses': 543,
#  'yeasts': 544,
#  'super': 545,
#  'herb': 546,
#  'rich': 547,
#  'anti-oxidant': 548,
#  'phytochemical': 549,
#  'flavonoids': 550,
#  'phenolic': 551,
#  'acids': 552,
#  'third': 553,
#  'highest': 554,
#  'oxygen': 555,
#  'radical': 556,
#  'absorbancy': 557,
#  'capacity': 558,
#  'orac': 559,
#  ')': 560,
#  'impressive': 561,
#  'score': 562,
#  '200': 563,
#  '129': 564,
#  'usda': 565,
#  'ranks': 566,
#  "oregano's": 567,
#  'antioxidant': 568,
#  'anywhere': 569,
#  'from': 570,
#  '20': 571,
#  'higher': 572,
#  'can': 573,
#  'bottles': 574,
#  'oreganol': 575,
#  'p73': 576,
#  'fridge': 577,
#  'wowww': 578,
#  'miraculously': 579,
#  'discomfort': 580,
#  'dryness': 581,
#  'throat': 582,
#  'then': 583,
#  'couple': 584,
#  'drops': 585,
#  'tablespoon': 586,
#  'water': 587,
#  'drank': 588,
#  'healed': 589,
#  'soothed': 590,
#  'instantly': 591,
#  'feel': 592,
#  'another': 593,
#  'body': 594,
#  'aching': 595,
#  'set': 596,
#  'seconds': 597,
#  'fantastic': 598,
#  '!!!': 599,
#  'emergency': 600,
#  'medicine': 601,
#  'eliminate': 602,
#  'digestive': 603,
#  'distress': 604,
#  'eating': 605,
#  'contaminated': 606,
#  'food': 607,
#  'fact': 608,
#  'easily': 609,
#  'read': 610,
#  'measurements': 611,
#  'those': 612,
#  "who's": 613,
#  'eyes': 614,
#  "aren't": 615,
#  'lol': 616,
#  'tired': 617,
#  'numbers': 618,
#  'others': 619,
#  'cup': 620,
#  'itself': 621,
#  'several': 622,
#  'seller': 623,
#  'green': 624,
#  'coffee': 625,
#  'exactly': 626,
#  'says': 627,
#  'am': 628,
#  'purchase': 629,
#  'finished': 630,
#  'bottle': 631,
#  'extremely': 632,
#  'electric': 633,
#  'blanket': 634,
#  'we': 635,
#  '&': 636,
#  'both': 637,
#  'cannot': 638,
#  'wires': 639,
#  'material': 640,
#  'luxurious': 641,
#  'quite': 642,
#  'pricey': 643,
#  '$50': 644,
#  'ones': 645,
#  'being': 646,
#  'indicates': 647,
#  'lover': 648,
#  'want': 649,
#  'flavor': 650,
#  'clean': 651,
#  'figured': 652,
#  'fit': 653,
#  'dasani': 654,
#  'able': 655,
#  'dinnerware': 656,
#  'aesthetic': 657,
#  'allow': 658,
#  'decoratively': 659,
#  'beauty': 660,
#  'white': 661,
#  'goes': 662,
#  'scheme': 663,
#  'acquiring': 664,
#  'already': 665,
#  'owned': 666,
#  'plain': 667,
#  ';': 668,
#  'platinum': 669,
#  'rim': 670,
#  'nicer': 671,
#  'sides': 672,
#  'match': 673,
#  'tan': 674,
#  'became': 675,
#  'blackish': 676,
#  'parts': 677,
#  'unpleasant': 678,
#  "can't": 679,
#  'since': 680,
#  'pain': 681,
#  'tolerance': 682,
#  'facial': 683,
#  'hair': 684,
#  'remover': 685,
#  'hurt': 686,
#  'face': 687,
#  'hate': 688,
#  'peach': 689,
#  'fuzz': 690,
#  'wearing': 691,
#  'foundation': 692,
#  'tweezers': 693,
#  'okay': 694,
#  'loved': 695,
#  'hard': 696,
#  'package': 697,
#  'bubble': 698,
#  'wrapped': 699,
#  'cute': 700,
#  'mine': 701,
#  'got': 702,
#  'smashed': 703,
#  'process': 704,
#  'shipping': 705,
#  'customer': 706,
#  'service': 707,
#  'bag': 708,
#  'smaller': 709,
#  'version': 710,
#  'picture': 711,
#  'shows': 712,
#  'describes': 713,
#  'holds': 714,
#  'accommodate': 715,
#  'd3100': 716,
#  'lenses': 717,
#  'along': 718,
#  'charger': 719,
#  'gel': 720,
#  'eyeliner': 721,
#  'longer': 722,
#  'liked': 723,
#  'slanted': 724,
#  'apply': 725,
#  'mask': 726,
#  'purpose': 727,
#  'keeping': 728,
#  'light': 729,
#  'hubs': 730,
#  'gets': 731,
#  '4am': 732,
#  'butthead': 733,
#  'turning': 734,
#  'lights': 735,
#  'getting': 736,
#  'ive': 737,
#  'havent': 738,
#  'issues': 739,
#  'sleeping': 740,
#  'through': 741,
#  'mini': 742,
#  'bra': 743,
#  'traditional': 744,
#  'flat': 745,
#  'sleep': 746,
#  'masks': 747,
#  'lay': 748,
#  '&#34': 749,
#  'cups&#34': 750,
#  'touch': 751,
#  'eyelids': 752,
#  'itchy': 753,
#  'reason': 754,
#  'why': 755,
#  'didnt': 756,
#  'give': 757,
#  'whenever': 758,
#  'turned': 759,
#  'kinda': 760,
#  'uncomfortable': 761,
#  'make': 762,
#  'stay': 763,
#  ':(': 764,
#  'photoshoot': 765,
#  '..': 766,
#  'cool': 767,
#  'vintage': 768,
#  'awesome': 769,
#  'gl/5zi8i': 770,
#  '600mg': 771,
#  'tablet': 772,
#  'cents': 773,
#  'additional': 774,
#  'biochemical': 775,
#  'pharmacological': 776,
#  'studies': 777,
#  'identified': 778,
#  'red': 779,
#  'yeast': 780,
#  'rice': 781,
#  'beneficial': 782,
#  'maintaining': 783,
#  'healthy': 784,
#  'balance': 785,
#  'cholesterol': 786,
#  'related': 787,
#  'lipids': 788,
#  'reported': 789,
#  'lowering': 790,
#  'ldl': 791,
#  'triglycerides': 792,
#  'while': 793,
#  'increasing': 794,
#  'hdl': 795,
#  'clinical': 796,
#  'patients': 797,
#  'who': 798,
#  'suffered': 799,
#  'heart': 800,
#  'attack': 801,
#  'partially': 802,
#  'purified': 803,
#  'extract': 804,
#  'reduced': 805,
#  'risk': 806,
#  'repeat': 807,
#  '45': 808,
#  'revascularization': 809,
#  'bypass': 810,
#  'surgery/angioplasty': 811,
#  'cardiovascular': 812,
#  'mortality': 813,
#  'total': 814,
#  'one-third': 815,
#  'cancer': 816,
#  'two-thirds': 817,
#  'nattokinase': 818,
#  'combined': 819,
#  'lower': 820,
#  'nattokinase(': 821,
#  'gl/32eeb': 822,
#  'fabulous': 823,
#  'job': 824,
#  'reducing': 825,
#  'overall': 826,
#  'cholesterol(': 827,
#  '220': 828,
#  '150': 829,
#  ').': 830,
#  'amazing': 831,
#  'reviews': 832,
#  'fake': 833,
#  'buyer': 834,
#  'ware': 835,
#  'blood': 836,
#  'stool': 837,
#  'stopped': 838,
#  'right': 839,
#  'away': 840,
#  'positive': 841,
#  'thing': 842,
#  'reviewer': 843,
#  'anyone': 844,
#  'write': 845,
#  '1': 846,
#  'star': 847,
#  'review': 848,
#  'no-one': 849,
#  'gl/5hndv': 850,
#  "biotin's": 851,
#  'role': 852,
#  'multi-faceted': 853,
#  'number': 854,
#  'nails': 855,
#  'biotin': 856,
#  'help': 857,
#  'grow': 858,
#  'treat': 859,
#  'brittle': 860,
#  'toe': 861,
#  'fingernails': 862,
#  'alopecia': 863,
#  'people': 864,
#  'premature': 865,
#  'gray': 866,
#  'levels': 867,
#  'helped': 868,
#  'combat': 869,
#  'graying': 870,
#  'candida': 871,
#  'changing': 872,
#  'fungal': 873,
#  'form': 874,
#  'fat': 875,
#  'burner': 876,
#  'often': 877,
#  'promoted': 878,
#  '"': 879,
#  'principle': 880,
#  'roles': 881,
#  'metabolism': 882,
#  'fats': 883,
#  'proteins': 884,
#  'carbs': 885,
#  '4': 886,
#  'reduce': 887,
#  'sugar': 888,
#  'cases': 889,
#  'doctors': 890,
#  'diabetes': 891,
#  'gene': 892,
#  'replication': 893,
#  'deeper': 894,
#  'level': 895,
#  'integral': 896,
#  'cells': 897,
#  'bone': 898,
#  'marrow': 899,
#  'production': 900,
#  'thinning': 901,
#  'working': 902,
#  'stressful': 903,
#  'point': 904,
#  "couldn't": 905,
#  'successfully': 906,
#  'ponytail': 907,
#  'decided': 908,
#  'try': 909,
#  'report': 910,
#  'stronger': 911,
#  'thicker': 912,
#  "haven't": 913,
#  'seen': 914,
#  'growth': 915,
#  'length': 916,
#  'prettier': 917,
#  'manageable': 918,
#  'hairdresser': 919,
#  'surprised': 920,
#  'went': 921,
#  'her': 922,
#  'trim': 923,
#  'haircut': 924,
#  'normally': 925,
#  'reach': 926,
#  ':)': 927,
#  'calcium': 928,
#  'hampers': 929,
#  'burning': 930,
#  'october': 931,
#  'losing': 932,
#  'dont': 933,
#  'care': 934,
#  'contains': 935,
#  'going': 936,
#  'worked': 937,
#  'expected': 938,
#  'lightweight': 939,
#  'durable': 940,
#  'perfect': 941,
#  'wife': 942,
#  'although': 943,
#  'still': 944,
#  'spare': 945,
#  'stylus': 946,
#  'pens': 947,
#  'know': 948,
#  'gl/xv1lp': 949,
#  'pine': 950,
#  'bark': 951,
#  'treating': 952,
#  '50': 953,
#  'diseases': 954,
#  'associated': 955,
#  'effects': 956,
#  'radicals': 957,
#  'prevention': 958,
#  'against': 959,
#  ':<': 960,
#  'asthma': 961,
#  '<': 962,
#  'chronic': 963,
#  'venous': 964,
#  'insufficiency': 965,
#  'condition': 966,
#  'involves': 967,
#  'leg': 968,
#  'swelling': 969,
#  'varicose': 970,
#  'veins': 971,
#  'itching': 972,
#  'changes': 973,
#  ')<': 974,
#  'pressure': 975,
#  'hypertension': 976,
#  'retinopathy': 977,
#  'eye': 978,
#  'commonly': 979,
#  'caused': 980,
#  'attention': 981,
#  'deficit': 982,
#  'hyperactivity': 983,
#  'disorder': 984,
#  'adhd': 985,
#  '7': 986,
#  'clots': 987,
#  'legs': 988,
#  'deep': 989,
#  'vein': 990,
#  'thrombosis': 991,
#  '9': 992,
#  'impotence': 993,
#  'known': 994,
#  'erectile': 995,
#  'dysfunction': 996,
#  'ed': 997,
#  '10': 998,
#  'male': 999,
#  'infertility': 1000,
#  ...}

# %% [markdown]
# # Evaluate on test set

# %%
from sklearn.metrics import precision_recall_fscore_support

# Finally, check the accuracy of your classifier by training on all the tranin data
# and testing on the test set
# Will only work once all functions are complete
functions_complete = True  # set to True once you're happy with your methods for cross val
if functions_complete:
    print(testData[0])   # have a look at the first test data instance
    classifier = trainClassifier(trainData)  # train the classifier
    testTrue = [t[1] for t in testData]   # get the ground-truth labels from the data
    testPred = predictLabels(testData_noLab, classifier)  # classify the test data to get predicted labels
    finalScores = precision_recall_fscore_support(testTrue, testPred, average='weighted') # evaluate
    print("Done training!")
    print("Precision: %f\nRecall: %f\nF Score:%f" % finalScores[:3])
# Out:
# ({'this': 0.08695652173913043, 'assortment': 0.043478260869565216, 'is': 0.043478260869565216, 'really': 0.043478260869565216, "hershey's": 0.043478260869565216, 'at': 0.043478260869565216, 'their': 0.043478260869565216, 'best': 0.043478260869565216, '.': 0.08695652173913043, 'the': 0.08695652173913043, 'little': 0.043478260869565216, 'ones': 0.043478260869565216, 'are': 0.043478260869565216, 'always': 0.043478260869565216, 'excited': 0.043478260869565216, 'whenever': 0.043478260869565216, 'holidays': 0.043478260869565216, 'come': 0.043478260869565216, 'because': 0.043478260869565216, 'of': 0.043478260869565216}, '__label1__')
# Training Classifier...
# Done training!
# Precision: 0.642248
# Recall: 0.642143
# F Score:0.642077

# %% [markdown]
# ### Having tried various values for the regularisation parameter C (0.5, 1, 2, 3, 4, 5), it was found that a value of 2 gives the best improvement in accuracy metrics, as we can see above. We can see that all the accuracy scores have improved from using weighted values for the tokens with the default regularisation parameter.
